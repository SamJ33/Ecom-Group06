# %%
import pandas as pd
import os

df_geo = pd.read_csv("C:/Users/user/Desktop/Ecom/data/raw/olist_geolocation_dataset.csv")
df_geo.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd # type: ignore
#       2 import os
#       4 df_geo = pd.read_csv("C:/Users/user/Desktop/Ecom/data/raw/olist_geolocation_dataset.csv")
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df_geo.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_geo.shape()
#
# NameError: name 'df_geo' is not defined

# %%
df_geo.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 38.2 MB

# %%
df_geo.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
df_geo["geolocation_zip_code_prefix"].duplicated().sum()
# Out:
# np.int64(981148)

# %%
df_geo_clean = (
    df_geo
    .groupby("geolocation_zip_code_prefix")
    .agg({
        "geolocation_lat": "mean",
        "geolocation_lng": "mean",
        "geolocation_city": "first",
        "geolocation_state": "first"
    })
    .reset_index()
)

# %%
df_geo_clean["geolocation_city"] = (
    df_geo_clean["geolocation_city"]
    .str.strip()
    .str.title()
)

df_geo_clean["geolocation_state"] = (
    df_geo_clean["geolocation_state"]
    .str.strip()
    .str.upper()
)

# %%
df_geo_clean.shape
# Out:
# (19015, 5)

# %%
df_geo_clean["geolocation_zip_code_prefix"].is_unique
# Out:
# True

# %%
import os

os.makedirs("C:/Users/user/Desktop/Ecom/data/processed", exist_ok=True)

# %%
df_geo_clean.to_csv(
    "C:/Users/user/Desktop/Ecom/data/processed/geolocation_cleaned.csv",
    index=False
)
